# %% [markdown]
# # Top10 Topic Youtube Crawler
#
# - Topic 관련 유튜브 크롤러
# - contents는 트위터 내 기사
# - comments
#
# #
# ![jpeg](https://www.glassmanwealth.com/wp-content/uploads/2015/10/alltwitter-twitter-bird-logo-white-on-blue.png)
#
# #

# %%
import os
import sys
import urllib.request
import json
from textblob import TextBlob
import nltk   
import tweepy
import config
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
import re
import time
from googletrans import Translator
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('movie_reviews')

# 트위터
# 컨슈머키 
# KqposylasMpKJvrKcUt5u1qf2
# MyMrf4mbci7eWewZ0cgIV3rQKteek8MEuCURh5M6Sr0mc3fYoi
# consumer_key = config.consumer_key
# consumer_secret = config.consumer_secret

consumer_key = 'KqposylasMpKJvrKcUt5u1qf2'
consumer_secret ='MyMrf4mbci7eWewZ0cgIV3rQKteek8MEuCURh5M6Sr0mc3fYoi'

# 엑세스토큰
# 413828241-YD0khaiuEUUK6BQGRevzNU2j1nZBqOXTPysDLKkQ
# oxPsaULAKkTPUjwtdS3JYsBSvZ5WNPYQoIcKR0W1i7the
# access_token = config.access_token
# access_token_secret = config.access_token_secret

access_token = '413828241-YD0khaiuEUUK6BQGRevzNU2j1nZBqOXTPysDLKkQ'
access_token_secret = 'oxPsaULAKkTPUjwtdS3JYsBSvZ5WNPYQoIcKR0W1i7the'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
# Out:
# [nltk_data] Downloading package punkt to /home/apostcto/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/apostcto/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /home/apostcto/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!

# %%
topics = ['society', 'politics', 'economic', 'foreign', 'culture',
          'entertain', 'sports', 'digital']

total_keyword_ranking10 = [['한유총', '개학연기', '유치원', '개학', '연기', '미세먼지', '사립유치원', '기자회견', '교육감', '수도권'],
 ['대통령', '독립유공자', '황교안', '해외', '후손', '문희상', '국회', 'NSC', '5당', '오찬'],
 ['판매', '은행', '부동산신탁업', '삼겹살', '신영한투대신', '3월', '예비인가', '친환경차', '신학기', '돌파'],
 ['트럼프', '볼턴', '2020', '김정은', '대통령', '빅딜', '미중', '무역협상', '문서', '중국'],
 ['미세먼지', '벚꽃', '대체로', '현재', '전국', '오후', '유치원', '수도권', '오전', '개학연기'],
 ['보스', '문제적', '이정현', '신동엽', '결혼', '샤이니', '정준호', '모범납세자', '장동민', '표창'],
 ['우승', '박성현', '감독', '서울', '스타즈', '정규리그', '승리', '시즌', '황현수', '개막전'],
 ['S10', '갤럭시', '갤럭시S10', '개통', '출시', 'KT', '시작', '5G', '함께한', '카카오']]

# %%
def tweet_crawl(keyword):
    
    tweet_list = []
    tweet_news_list = []
    
    tweet_count = 0
    tweet_news_count = 0
    
    public_tweets_ko = api.search(keyword,lang='ko',count='100')
    
    for tweet in public_tweets_ko:
        
        tweet = tweet.text
            
        # 트위터에서 'RT'라 적힌 부분은 지워줍니다
        if 'RT' in tweet:
            replace_index = tweet.find(':')
            tweet = tweet[replace_index+2:]
        
        if 'http' in tweet:
            tweet_news_list.append(tweet)
            tweet_news_count += 1
                
        else:
            tweet_list.append(tweet)
            tweet_count += 1
            
        time.sleep(1)
    
    return tweet_list, tweet_news_list, tweet_count, tweet_news_count

# %%
from joblib import Parallel, delayed

keyword_tweet_list = []
keyword_tweet_news_list = []
keyword_tweet_count = []
keyword_tweet_news_count = []
keyword_tweet_count_after30 = []
keyword_tweet_news_count_after30 = []

for i in range(2):
    
    topic_index = 0
    
    start_time = time.time()
    
    for topic in topics:
    
        print('{}분야를 검색합니다'.format(topic))
    
        # top10 키워드별로 검색
            
        tweet_info = Parallel(n_jobs=-1)(delayed(tweet_crawl)(keyword) for keyword in total_keyword_ranking10[topic_index])
            
        for tweet in tweet_info:
                
            keyword_tweet_list.append(tweet[0])
            keyword_tweet_news_list.append(tweet[1])
            
            if(i==1):
                keyword_tweet_count_after30.append(tweet[2])
                keyword_tweet_news_count_after30.append(tweet[3])
            else:
                keyword_tweet_count.append(tweet[2])
                keyword_tweet_news_count.append(tweet[3])
            
        
        time.sleep(5)
        topic_index+=1
    
    print('\n')
    print("총 걸린시간 : {}분".format(round((time.time() - start_time)/60, 1)))
    print('\n')
    
    if(i == 0):
        time.sleep(1800)
        print('30분 sleep\n')
# Out:
# society분야를 검색합니다
# politics분야를 검색합니다
# economic분야를 검색합니다
# foreign분야를 검색합니다
# culture분야를 검색합니다
# entertain분야를 검색합니다
# sports분야를 검색합니다
# digital분야를 검색합니다
#
#
# 총 걸린시간 : 14.3분
#
#
# 30분 sleep
#
# society분야를 검색합니다
# politics분야를 검색합니다
# economic분야를 검색합니다
# foreign분야를 검색합니다
# culture분야를 검색합니다
# entertain분야를 검색합니다
# sports분야를 검색합니다
# digital분야를 검색합니다
#
#
# 총 걸린시간 : 14.3분

# %%
keyword_tweet_list = keyword_tweet_list[0:80]
keyword_tweet_news_list = keyword_tweet_news_list[0:80]

# %%
# 30분 sleep 후 크롤링을 통해 트윗 추정량 측정

estimated_tweet = []
estimated_tweet_news = []

for i in range(len(keyword_tweet_count)):
    try:
        tweet_change = 48 * (keyword_tweet_count_after30[i] / (keyword_tweet_count[i]+keyword_tweet_count_after30[i]))
        estimated_tweet.append(round(keyword_tweet_count_after30[i] * tweet_change))
    except:
        estimated_tweet.append(0)
for i in range(len(keyword_tweet_news_count)):
    try:
        tweet_change = 48 * (keyword_tweet_news_count[i] / (keyword_tweet_news_count[i]+keyword_tweet_news_count_after30[i]))
        estimated_tweet_news.append(round(keyword_tweet_news_count_after30[i] * tweet_change))
    except:
        estimated_tweet_news.append(0)

# %%
# dataframe 길이를 맞추기 위한 형식

topics_80 = []
keyword_80 = sum(total_keyword_ranking10, [])


for topic in topics:
    for i in range(10):
        topics_80.append(topic)
        
company_list = ['Twitter' for _ in range(80)]
title_list = ['NaN' for _ in range(80)]



keyword_comment_ratio = []

for i in range(len(estimated_tweet)):
    try:
        ratio = estimated_tweet[i] / estimated_tweet_news[i]
        keyword_comment_ratio.append(ratio)
    except:
        keyword_comment_ratio.append(0)

# %%
import pandas as pd

Tweet_dataframe = pd.DataFrame({'Topic':topics_80,
                                'Keyword' : keyword_80,
                                'Company' : company_list,
                                'Title' : title_list,
                                'Contents' : keyword_tweet_list,
                                'Comments' : keyword_tweet_news_list,
                                'KC' : estimated_tweet,
                                'KCC' : estimated_tweet_news,
                                'KCR' : keyword_comment_ratio})

Tweet_dataframe
# Out:
#         Topic Keyword  Company Title  \
# 0     society     한유총  Twitter   NaN
# 1     society    개학연기  Twitter   NaN
# 2     society     유치원  Twitter   NaN
# 3     society      개학  Twitter   NaN
# 4     society      연기  Twitter   NaN
# 5     society    미세먼지  Twitter   NaN
# 6     society   사립유치원  Twitter   NaN
# 7     society    기자회견  Twitter   NaN
# 8     society     교육감  Twitter   NaN
# 9     society     수도권  Twitter   NaN
# 10   politics     대통령  Twitter   NaN
# 11   politics   독립유공자  Twitter   NaN
# 12   politics     황교안  Twitter   NaN
# 13   politics      해외  Twitter   NaN
# 14   politics      후손  Twitter   NaN
# 15   politics     문희상  Twitter   NaN
# 16   politics      국회  Twitter   NaN
# 17   politics     NSC  Twitter   NaN
# 18   politics      5당  Twitter   NaN
# 19   politics      오찬  Twitter   NaN
# 20   economic      판매  Twitter   NaN
# 21   economic      은행  Twitter   NaN
# 22   economic  부동산신탁업  Twitter   NaN
# 23   economic     삼겹살  Twitter   NaN
# 24   economic  신영한투대신  Twitter   NaN
# 25   economic      3월  Twitter   NaN
# 26   economic    예비인가  Twitter   NaN
# 27   economic    친환경차  Twitter   NaN
# 28   economic     신학기  Twitter   NaN
# 29   economic      돌파  Twitter   NaN
# ..        ...     ...      ...   ...
# 50  entertain      보스  Twitter   NaN
# 51  entertain     문제적  Twitter   NaN
# 52  entertain     이정현  Twitter   NaN
# 53  entertain     신동엽  Twitter   NaN
# 54  entertain      결혼  Twitter   NaN
# 55  entertain     샤이니  Twitter   NaN
# 56  entertain     정준호  Twitter   NaN
# 57  entertain   모범납세자  Twitter   NaN
# 58  entertain     장동민  Twitter   NaN
# 59  entertain      표창  Twitter   NaN
# 60     sports      우승  Twitter   NaN
# 61     sports     박성현  Twitter   NaN
# 62     sports      감독  Twitter   NaN
# 63     sports      서울  Twitter   NaN
# 64     sports     스타즈  Twitter   NaN
# 65     sports    정규리그  Twitter   NaN
# 66     sports      승리  Twitter   NaN
# 67     sports      시즌  Twitter   NaN
# 68     sports     황현수  Twitter   NaN
# 69     sports     개막전  Twitter   NaN
# 70    digital     S10  Twitter   NaN
# 71    digital     갤럭시  Twitter   NaN
# 72    digital  갤럭시S10  Twitter   NaN
# 73    digital      개통  Twitter   NaN
# 74    digital      출시  Twitter   NaN
# 75    digital      KT  Twitter   NaN
# 76    digital      시작  Twitter   NaN
# 77    digital      5G  Twitter   NaN
# 78    digital     함께한  Twitter   NaN
# 79    digital     카카오  Twitter   NaN
#
#                                              Contents  \
# 0   [한유총사태는 아직 해결된게 아니다. 어쩌면 이제부터 시작이다. 에듀파인 도입과 본...
# 1   [한유총이 무조건 ‘개학연기투쟁’ 중단했다. 한유총은 이번 책임은 정부와 민주당에 ...
# 2   [한유총사태는 아직 해결된게 아니다. 어쩌면 이제부터 시작이다. 에듀파인 도입과 본...
# 3   [[RT이벤트] 오늘 개학했으면 알티. #RT이벤트 #도미노피자 (2명, 3/7 발...
# 4   [한유총이 무조건 ‘개학연기투쟁’ 중단했다. 한유총은 이번 책임은 정부와 민주당에 ...
# 5   [아...... 학원에서 연락왓는데 왜 오늘 오후에 면접보자는거야 미세먼지 미쳣눈데...
# 6   [광주 사립유치원은 100% 정상 개학. 이 와중에 빛나브렀고요., 한유총은 일단 ...
# 7   [문자 왜 보내냐고? 대비하라고 보내는거야 왜 친절하게 보내줘도 ㅈㄹ이니.. 박근혜...
# 8   [한유총이 막판에 꺼낸 카드가\n좌파정부론인데\n유치원생들 학부모가 60, 70대가...
# 9   [[수도권 10:07 분 현재] 사고: (국도46호선)가평 군청입구교차로(춘천방향)...
# 10  [@yonhaptweet 유시민? ㅋㅋㅋ 노무현귀신전도사가 대통령후보2위? .. 리...
# 11  [문워크 영상 올라 왔는데 넘 잛음ㅋ\n해외 독립유공자 후손자 청와대\n초청. 울 ...
# 12  [12년 만에 3만불 넘었다..작년 1인당 국민소득 3만1천349달러\n\n황교안 ...
# 13  [뉴스타파가 OCCRP 등 해외매체와 함께 리투아니아 유키오 은행에서 유출된 사상 ...
# 14  [문워크 영상 올라 왔는데 넘 잛음ㅋ\n해외 독립유공자 후손자 청와대\n초청. 울 ...
# 15  [이태호 2차관은 2.28(목) 국회 의원회관에서 개최된 '한-메콩 정상회의 격상 ...
# 16  [정장 크로키 하고싶다 정장 전투 크로키는 국회싸움, 한유총 조지는 거 보니 한편으...
# 17  [문재인 대통령은 오늘(4일) 국가안전보장회의(NSC)를 개최해 2차 북미정상회담을...
# 18  [#10시_부산뉴스\n③ 청년에게 일자리를, 기업에는 인건비를! 부산시가 '청년고용...
# 19  [청와대 영빈관에서 열린 해외 독립유공자 후손 초청 오찬에 \n순국 선열들의 후손들...
# 20  [&lt;위저드 베이커리&gt; 구병모 신작 &lt;버드스트라이크&gt; 예약 판매...
# 21  [이명박 전 대통령의 국제자문위원 ‘루벤 바르다니안’이 이번에 적발된 10조원 규모...
# 22  [신영증권·한국금융지주·대신증권 등 증권사 3곳이 부동산신탁업 진출에 성공함. 부동...
# 23  [@KossacK_co 고등어와 삼겹살 구워먹는걸 자제하는 나라..., 181201...
# 24                                                 []
# 25  [🍬정국이를 위한 화이트데이 이벤트🍬\n\n작년 아미들에게 꾹헤돼를 선물했던 정국이...
# 26  [@002_Strelizia 후후후, 쿡쿡. 어리석게도 음란에게 건네진 그 예비열쇠...
# 27  [◆ 대 상 : 공공기관 직원차량(경차포함)\n◆ 제외차량 : 친환경차, 장애인 및...
# 28  [신학기 인싸되는법\n1. 카톡 프사는 반드시 치노프사로!\n2. 반에 들어오자마자...
# 29  [Jus2 “FOCUS ON ME” M/V 1000만 돌파! 또 하나의 멋진 선물을...
# ..                                                ...
# 50  [문제는... 라이더가 마지막 보스인데 어쌔신 죽으면 똥망되는, 보스..., 주인공...
# 51  ["&lt;문제적 남자&gt; 라는 프로그램에서 손 그림으로 된 암호를 보여주고, ...
# 52  [경남·호남-\n강석진(산청·함양·거창·산청) 박대출(진주 갑) 박완수(창원 의창)...
# 53  [ㅋㅋㅋㅋㅋ방금 미운우리새끼에서 신동엽이 다음에 태어나면 여자로 태어나고 싶다고, ...
# 54  [나랑 결혼하겠다는 남자애 눈을 찌르기도 했었지, 아마?, 어떤 딸이 크면 아빠랑 ...
# 55  [#샤이니 #민호 가 30일 서울 앙코르 팬미팅으로 2월부터 펼쳐졌던 첫 단독 팬미...
# 56  ["드라마 후반부에 사무실을 찾아온 정준호에게 멱살을 잡히고 패대기쳐지는 장면에선 ...
# 57  [이제훈은 "모범납세자로 선정된 것만으로도 영광인데 대통령 표창이라는 큰 상까지 주...
# 58  [@Mysticblue1024 그래도 그 흉물이 유세윤, 장동민, 유상무, 기안84...
# 59  [@wwwwwwlaugh 기자도 미성년자 성매수했나 왜때문에 성매수남한테 이입하는거...
# 60  [@zer0zoner ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ원진님 입맛에 맞으셔서 다행이에요! 이...
# 61  [@sh_tweet0404 어머니 완전 멋지셔요👍👍 박성현 선수가 매번 우승했으면 ...
# 62  [배우들, 감독님 총출동! \n광대 승천 예상되는 제작발표회\n이따 오후 2시에 만...
# 63  [#샤이니 #민호 가 30일 서울 앙코르 팬미팅으로 2월부터 펼쳐졌던 첫 단독 팬미...
# 64  [킹 오브 프리즘 –샤이니 세븐 스타즈-\n&lt;극장판 한정 쿠키 영상&gt; 안...
# 65  [대한항공 17/18시즌 챔프우승할때영상 받는데 눈물이 나올까말까 이번에도 V2할수...
# 66  [안녕하세요! 뱅가드 파이터 여러분들!\n3월 2주차와 3월 3주차 카드파이트!! ...
# 67  [SM ‘STATION’ 시즌 3의 여덟 번째 주인공! ‘대체불가 걸그룹’ 레드벨벳...
# 68  [@IIsanghaesssi 황현수 어린 중앙수비수 ㅇㅇ 9번 우즈벡에서도 유망주임...
# 69  [어디는 내일 개막전 예매라는데 좌석 요금표도 안 내놓은 으메이징 솩런트, 깡통 돌...
# 70  [여전히 낙서의 굴레에서 벗어나지 못하는... 현제유진으로 센티널버스 보고싶어서 그...
# 71  [@Apongs 오버워치 &lt;&lt;&lt;넘사벽&lt;&lt;&lt;넘사벽2&...
# 72  [#iKON x Samsung #GalaxyS10 Launch Event at Ba...
# 73  [삼성 공식에서 갨텐 예판 탄 사람들 아직도 발송 안떴다고 다들 불타고있네 ㄷㄷ 하...
# 74  [앜 드디어 스파오 콜라보 소식이 나왔네요!\n진짜 대박.... 완전 이번에 작정하...
# 75  [KT에서 어제 출시한 따끈따끈한 미세먼지 앱 AirMapKorea. 공중전화 부스...
# 76  [&lt;6th album CATCH ME&gt; 이번 앨범은 열쇠 같아요. 더 넓...
# 77  [죽것다 5시까지 박고 못깸, 어떻게 6월 중순까지 이렇게 지내 말도 안대, 집 가...
# 78  [우리 인생에 수많은 사람들을 만나 어떤 인연을 맺고 끊을지 아무도 몰라요. 그렇지...
# 79  [▶모두가 당첨될때까지 114번째 이벤트❤️\n\n🎁가성비 블투 이어폰!\n▶201...
#
#                                              Comments    KC   KCC        KCR
# 0   [한유총 이덕선 이사장이 운영하는 리더스 유치원은 오늘 문 열었었다고 합니다. ㅋㅋ...  1488   912   1.631579
# 1   [한유총, 개학연기 강행 하루 만에 철회. 오늘(5일)부터 유치원 정상 운영하기로....   893  1364   0.654692
# 2   [한유총 이덕선 이사장이 운영하는 리더스 유치원은 오늘 문 열었었다고 합니다. ㅋㅋ...  1405   923   1.522210
# 3   [한유총, 개학연기 강행 하루 만에 철회. 오늘(5일)부터 유치원 정상 운영하기로....  1114   914   1.218818
# 4   [한유총, 개학연기 강행 하루 만에 철회. 오늘(5일)부터 유치원 정상 운영하기로....  1152  1139   1.011414
# 5   [많은사람들이 겪고있는 미세먼지 피해증상 https://t.co/3SPv2qEKHu...  1380   816   1.691176
# 6   [진짜 ‘세금 도둑’ 한유총 비호하는 자한당, 세월호 특조위 ‘만행’ 재조명\nht...  1561   741   2.106613
# 7   [＂아이 볼모 투쟁은 아동학대＂ 한유총 고발하는 학부모단체 https://t.co/...  1195  1152   1.037326
# 8   [서울시교육청, 한유총 법인인가 취소키로 확정\n조희연 교육감, 5일(화)오후 기자...  1920   431   4.454756
# 9   ['미세먼지도 재난' 법제화 눈앞…범정부 총력대응 강화\nhttps://t.co/7...   415  1493   0.277964
# 10  [문재인,여론조작으로 당선된 가짜 대통령!\n\n문재인게이트의 실체!\n\nhttp...  1309   948   1.380802
# 11  [잘 보이냐? 이 분이 국민만 믿고 가는 대통령이시다!! 이게 나라다!!! 나는 어...  1210   945   1.280423
# 12  [황교안 "文정부, 시장 살린다며 개입해 거꾸로 죽이고 있다"\nhttps://t....  1301  1367   0.951719
# 13  [유령회사 통해 삼성 해외법인에 천억 원대 유입\n유키오 통해 삼성에 송금한 회사들...  1462   659   2.218513
# 14  [잘 보이냐? 이 분이 국민만 믿고 가는 대통령이시다!! 이게 나라다!!! 나는 어...   996  1164   0.855670
# 15  [[인뉴스TV] 문희상 의장, ‘1919 유관순-그녀들의 조국’ 국회 시사회 참석\...  2004   372   5.387097
# 16  [40일 만에 ‘빈손 회군’한 나경원 “우리 결단으로 국회 열기로”@newsvop ...  1398   805   1.736646
# 17  [오늘 NSC 회의에 김현종도 참석. 사진마다 내가 조와하는 사람들 천지넴. 😊 h...   948  1212   0.782178
# 18  [황교안 "文정부, 시장 살린다며 개입해 거꾸로 죽이고 있다"\nhttps://t....  2265   559   4.051878
# 19  [독립유공자 후손을 대하시는 \n문재인 대통령님의 무릎. \n\n해외 독립유공자 후...  1145  1086   1.054328
# 20  [ど 배그핵/서든핵/옵치핵/에펙핵 최저가 판매처\n\nヮ 사이트이동 : https:...  1941   906   2.142384
# 21  [저도 은행에 가서 저의 얼굴이 담긴 카드를\n받고 싶었능데, 용기가 나지 않아서 ...  1824   499   3.655311
# 22  [신영·한투·대신, 부동산신탁업 예비인가…NH·키움은 탈락(종합) (출처 : 조선비...    48   432   0.111111
# 23  [냉동 삼겹살 한근5000원 미친물가의 재래시장때문에 요즘 삼겹살 물리게 먹고있다....  1492   936   1.594017
# 24  [신영·한투·대신, 부동산신탁업 예비인가…NH·키움은 탈락(종합) (출처 : 조선비...     0   456   0.000000
# 25  [샤이니 #민호, 30일 서울 앙코르 팬미팅 ‘더 베스트 초이스 민호’ 개최\nht...  1527   252   6.059524
# 26  [신영·한투·대신, 부동산신탁업 예비인가…NH·키움은 탈락(종합) (출처 : 조선비...  1224  1032   1.186047
# 27  [수소차  좀 많이 팔아라...친환경차 판매 증가, 수소전기차 780% 성장..日과...    48   900   0.053333
# 28  [[최자매공구샵] 신학기 메신저 가방 / 크로스백 / 데일리가방\n스트릿패션 / 화...  1680   623   2.696629
# 29  [EXO의 매력은 언제나 명중! It’s the Love Shot!\nEXO의 ‘L...  1796   298   6.026846
# ..                                                ...   ...   ...        ...
# 50  [그런데 얘 옷차림 예절 독특한 게 자기네 조직 최고 보스 만나는 간부회의때 옷 평...   569  1036   0.549228
# 51  [@bohemian_nn @muncan76 에이 선택적 정의가 거기서 왜나오나??\...  1836   288   6.375000
# 52  [grn 티르티르 티르티르 가수 이정현 나이 txt 뉴욕증시\n#정품ㅂㅣㅇㅏ그ㄹㅏ확...   318  1823   0.174438
# 53  [17#대전보도 #대전룸보도 #대전룸알바 #대전룸도우미 #대전룸알바 #대전룸아가씨 ...  1164  1260   0.923810
# 54  [초혼, 재혼, 국내결혼, 국제결혼, 테마가 있는 인연, 가람연 결혼정보 https...  1493   658   2.268997
# 55  [#빛나는샤이니 #SHINee #샤이니 @shinee \n건강하고 씩씩하게 ♥️ h...  1517   299   5.073579
# 56  [https://t.co/U02XJUaNLQ\n\n[풀영상] 신동엽ㆍ정준호ㆍ토니안,...   288  1584   0.181818
# 57  [정말 뜬금포 기사지만... 축하..\n\n[공식]차승원, 모범납세자 선정…'서울지...   216  2184   0.098901
# 58  [레드벨벳 Red Velvet 'IceCream Cake' 라이브 LIVE / 15...   312   720   0.433333
# 59  [정말 뜬금포 기사지만... 축하..\n\n[공식]차승원, 모범납세자 선정…'서울지...   667  1858   0.358988
# 60  [[진우승효] 해고듀스 101 원픽 https://t.co/PMMRY95XcI, 1...  1320  1031   1.280310
# 61  [[LPGA] 박성현, 4개월만에 세계랭킹 1위 복귀 https://t.co/13i...   300  2076   0.144509
# 62  [유지하는 중이었음. 코치나 감독도 유중혁이 최소한의 팀워크를 맞추는 시간이 아닌 ...   170   465   0.365591
# 63  [다크 서울 -재의 도시- https://t.co/uMvzWVFVkI, 러블리즈 케...  1390   422   3.293839
# 64  [일본 로리타패션 브랜드 '베이비 더 스타즈 샤인 브라이트' 소식입니다.\n3월 4...  2365     0   0.000000
# 65  ['박지수 16점' KB국민은행, 13년 만에 정규리그 우승\nhttps://t.c...   720  1680   0.428571
# 66  [승리 팀,벌칙 발표\n마크 표정ㅋㅋㅋㅋㅋㅋㅋ https://t.co/agxvz9O...   399  1268   0.314669
# 67  [SM ‘STATION’ 시즌 3의 여덟 번째 주인공! ‘대체불가 걸그룹’ 레드벨벳...  2102   160  13.137500
# 68  [‘골 넣는 수비수’ 황현수 ‘반전은 이제 시작’ (2019.03.04/뉴스데스크/...   336   624   0.538462
# 69  [류현진 개막전 선발, 최적의 대안으로 떠올라\nhttps://t.co/M2gIKZ...   889  1524   0.583333
# 70  [아직 전독시 읽고 있지만 \n독자의 하얀 코트 너무 그리고 싶었습니다 ^^;\n코...   157  1740   0.090230
# 71  [싸다 대박. 할인 사은품 장난아니네 갤럭시 s10 스펙 가격 정보 https://...   447   813   0.549815
# 72  [싸다 대박. 할인 사은품 장난아니네 갤럭시 s10 스펙 가격 정보 https://...   192  1835   0.104632
# 73  [경리와 함께한 KT 갤럭시 S10 사전개통행사 후기! https://t.co/Pn...  1555   576   2.699653
# 74  [🎊RT Event🎊\n\n✨막쳐라 용사단✨\n새 게임을 출시했습니다! \n(우선 ...   331  1158   0.285838
# 75  [경리와 함께한 KT 갤럭시 S10 사전개통행사 후기! https://t.co/Pn...  1050   202   5.198020
# 76  [하루의 시작은 #커피 와 함께!\n커피로 하루를 시작하는 #직딩 이라면\n출근 인...  1728   455   3.797802
# 77  [[App Ape의 모바일 앱 분석] HOME AI &amp; 5G VR AR &a...  1200  1200   1.000000
# 78  [180305 #임영민 #180305_영민\n공식 트위터\n오랜만에 다이아몬드뽀이들...  1536  1201   1.278934
# 79  [즉시입금/신속처리 골드상품권 ▶▶전화번호: O1O-5403-7652  ▶▶ 카카오...  1043  1070   0.974766
#
# [80 rows x 9 columns]

# %%
Tweet_dataframe.to_csv('tweet_dataframe', index=False)
